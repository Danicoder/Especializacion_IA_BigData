# %% [markdown]
# <a href="https://colab.research.google.com/github/Danicoder/Especializacion_IA_BigData/blob/main/Regresion_lineal_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

X = [1,2,3,4,5,6,7] #Período
Y = [7000,9000,5000,11000,10000,13000,14500] #Ventas
Z = [8,9] #mes de ventas a pronosticar (Agosto y Septiembre)

#Lo convertimso en matrices
x = np.array(X)
y = np.array(Y)
z = np.array(Z)

#gráfico de dispersión lineal
fig, ax = plt.subplots()
# Dibujar puntos
ax.plot(x,y,"b.")
ax.plot(x,lin_reg.predict(x.reshape(-1, 1)),"r-")
plt.title('Distribución entre Meses y Ventas');
plt.xlabel("Meses")
plt.ylabel("Ventas")
plt.show()

#Construcción de MODELO (aprendizaje supervisado)
lin_reg = LinearRegression()
lin_reg.fit(x.reshape(-1,1),y)

#parámetro de estimación con el punto de corte
print(f"El punto de corte de nuestro algoritmo es: {lin_reg.intercept_}")
#parámetro de estimación con la pendiente
print(f"La pendiente de nuestro algoritmo es: {lin_reg.coef_ }")

#Predición de ventas mensuales
predicion_meses = z.reshape(-1,1)
predicion_venta = lin_reg.predict(predicion_meses)
# Para los meses de Augosto y Septiembre
for mes, venta in zip(Z, predicion_venta):
    print(f"Pronostico para el mes {mes}: {venta}")

#Calculo del error cuadrático (MSE) medio para evaluar la calidad del modelo
y_true = y
y_pred = lin_reg.predict(x.reshape(-1,1)) #lin_reg.predict(x.reshape(-1,1))
mse = mean_squared_error(y, y_pred)
print(f"El error cuadrático medio es mse: {mse}")

#Cálculo de la Raíz del Error Cuadrático Medio (RMSE)
def rmse(actual, pred):
    actual, pred = np.array(actual), np.array(pred)
    return np.sqrt(np.mean((actual - pred) ** 2))

actual = lin_reg.predict(y.reshape(-1,1))
pred = y_pred
print(f"El valor de la raíz cuadrada de mse es rmse: {mse}")

#Cálculo de coeficiente de Determinación (R2)
r2 = lin_reg.score(x.reshape(-1,1), y)
print(f"El Coeficiente de Determinación es R2: {r2}")
# Out:
# El punto de corte de nuestro algoritmo es: 4857.14285714286
# La pendiente de nuestro algoritmo es: [1267.85714286]
# Pronostico para el mes 8: 15000.0
# Pronostico para el mes 9: 16267.857142857141
# El error cuadrático medio es mse: 2886479.5918367347
# El valor de la raíz cuadrada de mse es rmse: 2886479.5918367347
# El Coeficiente de Determinación es R2: 0.6901697699890472
