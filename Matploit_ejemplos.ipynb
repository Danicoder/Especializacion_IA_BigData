# %% [markdown]
# <a href="https://colab.research.google.com/github/Danicoder/Especializacion_IA_BigData/blob/main/Matploit_ejemplos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CREA UN GRÁFICO

# %%
import matplotlib.pyplot as plt
# Crear la figura y los ejes
fig, ax = plt.subplots()
# Dibujar puntos
ax.scatter(x = [1, 2, 3,4,5], y = [5,4,3, 2, 1])
# Guardar el gráfico en formato png
plt.savefig('Diagrama-Dispersion.png')
# Mostrar el gráfico
plt.show()

# %% [markdown]
# GRÁGICO DE DISPERSIÓN

# %%
fig, ax = plt.subplots()
ax.scatter([1, 2, 3, 4,5], [1, 2, 0, 0.5,1])
plt.show()

# %% [markdown]
# GRÁFICO DE LÍNEAS

# %%
fig, ax = plt.subplots()
ax.plot([1, 2, 3, 4], [1, 2, 0, 0.5])
plt.show()

# %% [markdown]
# GRÁFICO DE ÁREAS

# %%
fig, ax = plt.subplots()
ax.fill_between([1, 2, 3, 4,5], [1, 2, 0, 0.5,1.5])
plt.show()

# %% [markdown]
# GRÁFICO DE BARRAS HORIZONTALES

# %%
fig, ax = plt.subplots()
ax.barh([1, 2, 3], [3, 2, 1])
plt.show()

# %% [markdown]
# GRÁFICO DE HISTOGRAMAS

# %%
import numpy as np
fig, ax = plt.subplots()
x = np.random.normal(5, 1.5, size=1000)
ax.hist(x, np.arange(0, 11))
plt.show()

# %% [markdown]
# GRÁFICO DE LÍNEAS CON POSICIÓN DE LA LEYENDA

# %%
fig, ax = plt.subplots()
ax.plot([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ], [0. ,
0.25, 1. , 2.25, 4. , 6.25, 9. , 12.25, 16. , 20.25, 25.],label="valores")
plt.plot() # se grafica una línea de color azul
plt.title('Titulo de la Grafica'); # definir el titulo de la grafica
plt.xlabel('Eje X') # definir el nombre del eje X
plt.ylabel('Eje Y') # definir el nombre del eje Y
plt.legend(loc=1) #leyenda

# %% [markdown]
# GRÁFICO CON CAMBIO DE COLOR EN LAS LÍNEAS

# %%
import numpy as np
x = np.linspace(0,5, 11) #linspace(start, stop, num) donde num es el numero de muestras a generar
y = x ** 2
plt.subplot(1,2,1) # subplot fila=1 Col=2, grafica=1
plt.plot(x, y, 'r--') # r-- color rojo y línea discontinua
plt.subplot(1,2,2) # subplot fila=1 Col=2, grafica=2
plt.plot(y, x, 'g*-'); # para no mostrar info de la función
plt.tight_layout() # para que no se superpongan las graficas
