# %% [markdown]
# <a href="https://colab.research.google.com/github/Danicoder/Especializacion_IA_BigData/blob/main/PreparacionConjuntoDatos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##VISUALIZACION CONJUNTO DE DATOS

# %%
# !pip install liac-arff
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11716 sha256=fdf69aed6950e7333eeffda6f79af4987557b792b785381656a67db8125bf65e
#   Stored in directory: /root/.cache/pip/wheels/00/23/31/5e562fce1f95aabe57f2a7320d07433ba1cd152bcde2f6a002
# Successfully built liac-arff
# ...

# %%
from google.colab import files

import arff
import pandas as pd
import numpy as np
import sklearn.model_selection as model_selection
from sklearn.model_selection import train_test_split

# %%
uploaded1 = files.upload()
uploaded2 = files.upload()
# Out:
#      <input type="file" id="files-d44b030d-381d-4718-af9e-24369da87060" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d44b030d-381d-4718-af9e-24369da87060">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
def load_kdd_dataset(data_path):
    """Lectura del conjunto de datos NSL-KDD."""
    with open(data_path, 'r') as train_set:
        dataset = arff.load(train_set)
    attributes = [attr[0] for attr in dataset["attributes"]]
    return pd.DataFrame(dataset["data"], columns=attributes)
def train_val_test_split(df, rstate=42, shuffle=True,
stratify=None):
    strat = df[stratify] if stratify else None
    train_set, test_set = train_test_split(
        df, test_size=0.4, random_state=rstate,
shuffle=shuffle, stratify=strat)
    strat = test_set[stratify] if stratify else None
    val_set, test_set = train_test_split(
        test_set, test_size=0.5, random_state=rstate,
shuffle=shuffle, stratify=strat)
    return (train_set, val_set, test_set)

# %%
df = load_kdd_dataset("/content/KDDTrain%2B.arff")
df
# Out:
#         duration protocol_type   service  ... dst_host_rerror_rate  dst_host_srv_rerror_rate    class
# 0            0.0           tcp  ftp_data  ...                 0.05                      0.00   normal
# 1            0.0           udp     other  ...                 0.00                      0.00   normal
# 2            0.0           tcp   private  ...                 0.00                      0.00  anomaly
# 3            0.0           tcp      http  ...                 0.00                      0.01   normal
# 4            0.0           tcp      http  ...                 0.00                      0.00   normal
# ...          ...           ...       ...  ...                  ...                       ...      ...
# 125968       0.0           tcp   private  ...                 0.00                      0.00  anomaly
# 125969       8.0           udp   private  ...                 0.00                      0.00   normal
# ...

# %%
X = df.drop(columns=['class'])
y = df['class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42,stratify=df['protocol_type'])

# %%
Val_set = X_test
test_set = y_test
train_set = X_train

train_set, val_set, test_set = train_val_test_split(df, stratify='protocol_type')

# %%
print(f"Longitud del Test Set: {len(test_set)}")
print(f"Longitud del Validation Set: {len(Val_set)}")
print(f"Longitud del Training Set: {len(train_set)}")
# Out:
# Longitud del Test Set: 25195
# Longitud del Validation Set: 25195
# Longitud del Training Set: 75583

# %%
X_train = train_set.drop("class", axis=1)
y_train = train_set["class"].copy()

# %%
X_train_copy = X_train.copy()

# %%
entre400Y800_srcbytes = (X_train_copy["src_bytes"] > 400) & (X_train_copy["src_bytes"] < 800)
entre500Y2000_dstbytes = (X_train_copy["dst_bytes"] > 500) & (X_train_copy["dst_bytes"] < 2000)

X_train_copy.loc[entre400Y800_srcbytes, "src_bytes"] = np.nan
X_train_copy.loc[entre500Y2000_dstbytes, "dst_bytes"] = np.nan

# %% [markdown]
# Fichero X_train despues de añadir NaN:

# %%
X_train_copy
# Out:
#         duration protocol_type  ... dst_host_rerror_rate dst_host_srv_rerror_rate
# 113467       0.0           tcp  ...                  0.0                      0.0
# 31899        0.0           tcp  ...                  0.0                      0.0
# 108116       0.0           tcp  ...                  0.0                      0.0
# 89913        0.0           tcp  ...                  0.0                      0.0
# 106319       0.0          icmp  ...                  0.0                      0.0
# ...          ...           ...  ...                  ...                      ...
# 64559        0.0           tcp  ...                  0.0                      0.0
# 67272        0.0           tcp  ...                  0.0                      0.0
# 32452        3.0           tcp  ...                  0.0                      0.0
# 112657       0.0           tcp  ...                  0.0                      0.0
# ...

# %%
print(X_train_copy.isna().any())
# Out:
# duration                       False
# protocol_type                  False
# service                        False
# flag                           False
# src_bytes                       True
# dst_bytes                       True
# land                           False
# wrong_fragment                 False
# urgent                         False
# hot                            False
# num_failed_logins              False
# logged_in                      False
# num_compromised                False
# root_shell                     False
# su_attempted                   False
# num_root                       False
# num_file_creations             False
# num_shells                     False
# num_access_files               False
# num_outbound_cmds              False
# is_host_login                  False
# is_guest_login                 False
# count                          False
# srv_count                      False
# serror_rate                    False
# ...

# %%
X_train_copy
# Out:
#         duration protocol_type  ... dst_host_rerror_rate dst_host_srv_rerror_rate
# 113467       0.0           tcp  ...                  0.0                      0.0
# 31899        0.0           tcp  ...                  0.0                      0.0
# 108116       0.0           tcp  ...                  0.0                      0.0
# 89913        0.0           tcp  ...                  0.0                      0.0
# 106319       0.0          icmp  ...                  0.0                      0.0
# ...          ...           ...  ...                  ...                      ...
# 64559        0.0           tcp  ...                  0.0                      0.0
# 67272        0.0           tcp  ...                  0.0                      0.0
# 32452        3.0           tcp  ...                  0.0                      0.0
# 112657       0.0           tcp  ...                  0.0                      0.0
# ...

# %%
X_train_copy.src_bytes
X_train_copy.dst_bytes
# Out:
# 113467    53508.0
# 31899         0.0
# 108116        NaN
# 89913         0.0
# 106319        0.0
#            ...
# 64559         0.0
# 67272         NaN
# 32452       328.0
# 112657      444.0
# 99030      3127.0
# Name: dst_bytes, Length: 75583, dtype: float64

# %%
X_train_copy.dropna(subset=["src_bytes"], inplace=True)
X_train_copy.dropna(subset=["dst_bytes"], inplace=True)

# %%
num_filas_original = len(X_train)
num_filas_copia = len(X_train_copy)

filas_eliminadas = num_filas_original - num_filas_copia

print(f"Número de filas eliminadas: {filas_eliminadas}")
# Out:
# Número de filas eliminadas: 9886

# %%
copy2_X_train = X_train_copy.copy()

# %%
copy2_X_train.drop(["src_bytes", "dst_bytes"], axis=1, inplace=True)
copy2_X_train
# Out:
#         duration protocol_type  ... dst_host_rerror_rate dst_host_srv_rerror_rate
# 31899        0.0           tcp  ...                  0.0                      0.0
# 89913        0.0           tcp  ...                  0.0                      0.0
# 106319       0.0          icmp  ...                  0.0                      0.0
# 98007        0.0           udp  ...                  0.0                      0.0
# 16447        0.0           tcp  ...                  0.0                      0.0
# ...          ...           ...  ...                  ...                      ...
# 90665        0.0           tcp  ...                  0.0                      0.0
# 64559        0.0           tcp  ...                  0.0                      0.0
# 32452        3.0           tcp  ...                  0.0                      0.0
# 112657       0.0           tcp  ...                  0.0                      0.0
# ...

# %%
print(f"Número de atributos eliminados: {len(list(X_train_copy)) - len(list(copy2_X_train))}")
# Out:
# Número de atributos eliminados: 2

# %%
media_srcbytes = X_train_copy["src_bytes"].mean()
X_train_copy["src_bytes"].fillna(media_srcbytes, inplace=True)
# Out:
# <ipython-input-92-590f785bf950>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X_train_copy["src_bytes"].fillna(media_srcbytes, inplace=True)

# %% [markdown]
# RELLENAR VALORES DE ENTRENAMIENTO A NULOS

# %%
from sklearn.impute import SimpleImputer
Valor =SimpleImputer(strategy="median")

# %%
X_train_copy_num = X_train_copy.select_dtypes(exclude=['object'])
X_train_copy_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 65697 entries, 31899 to 99030
# Data columns (total 34 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   duration                     65697 non-null  float64
#  1   src_bytes                    65697 non-null  float64
#  2   dst_bytes                    65697 non-null  float64
#  3   wrong_fragment               65697 non-null  float64
#  4   urgent                       65697 non-null  float64
#  5   hot                          65697 non-null  float64
#  6   num_failed_logins            65697 non-null  float64
#  7   num_compromised              65697 non-null  float64
#  8   root_shell                   65697 non-null  float64
#  9   su_attempted                 65697 non-null  float64
#  10  num_root                     65697 non-null  float64
#  11  num_file_creations           65697 non-null  float64
# ...

# %%
imputer.fit(X_train_copy_num)
# Out:
# SimpleImputer(strategy='median')

# %%
X_train_copy_num_nonan = imputer.transform(X_train_copy_num)

# %%
X_train_copy = pd.DataFrame(X_train_copy_num_nonan,
columns=X_train_copy_num.columns)
X_train_copy_num
# Out:
#         duration  src_bytes  ...  dst_host_rerror_rate  dst_host_srv_rerror_rate
# 31899        0.0        0.0  ...                   0.0                       0.0
# 89913        0.0        0.0  ...                   0.0                       0.0
# 106319       0.0        8.0  ...                   0.0                       0.0
# 98007        0.0       46.0  ...                   0.0                       0.0
# 16447        0.0     1790.0  ...                   0.0                       0.0
# ...          ...        ...  ...                   ...                       ...
# 90665        0.0        0.0  ...                   0.0                       0.0
# 64559        0.0        0.0  ...                   0.0                       0.0
# 32452        3.0      889.0  ...                   0.0                       0.0
# 112657       0.0      284.0  ...                   0.0                       0.0
# 99030        0.0      209.0  ...                   0.0                       0.0
#
# ...

# %% [markdown]
# RELLENAR VALORES DE VALIDACION A NULOS

# %%
val_set_copy = val_set.copy()

# %%
val_set_copy_num = val_set_copy.select_dtypes(exclude=['object'])
val_set_copy_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25195 entries, 94285 to 97927
# Data columns (total 34 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   duration                     25195 non-null  float64
#  1   src_bytes                    25195 non-null  float64
#  2   dst_bytes                    25195 non-null  float64
#  3   wrong_fragment               25195 non-null  float64
#  4   urgent                       25195 non-null  float64
#  5   hot                          25195 non-null  float64
#  6   num_failed_logins            25195 non-null  float64
#  7   num_compromised              25195 non-null  float64
#  8   root_shell                   25195 non-null  float64
#  9   su_attempted                 25195 non-null  float64
#  10  num_root                     25195 non-null  float64
#  11  num_file_creations           25195 non-null  float64
# ...

# %%
val_set_copy_num_nonan = imputer.transform(val_set_copy_num)

# %%
val_set_copy = pd.DataFrame(val_set_copy_num_nonan, columns=val_set_copy_num.columns)
val_set_copy_num
# Out:
#         duration  src_bytes  ...  dst_host_rerror_rate  dst_host_srv_rerror_rate
# 94285        0.0      176.0  ...                  0.00                      0.00
# 42421        0.0        0.0  ...                  0.87                      0.96
# 94535        0.0      641.0  ...                  0.00                      0.00
# 103617       0.0        0.0  ...                  0.00                      0.00
# 44161        0.0        0.0  ...                  0.00                      0.00
# ...          ...        ...  ...                   ...                       ...
# 25371        0.0        0.0  ...                  0.00                      0.00
# 28431        0.0      202.0  ...                  0.00                      0.00
# 33933        0.0        0.0  ...                  0.00                      0.00
# 666          0.0       28.0  ...                  0.00                      0.00
# 97927        0.0        0.0  ...                  0.00                      0.00
#
# ...

# %% [markdown]
# RELLENAR VALORES DE PRUEBA A NULOS

# %%
test_set_copy = test_set.copy()

# %%
test_set_copy = test_set_copy.select_dtypes(exclude=['object'])
test_set_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25195 entries, 1219 to 107881
# Data columns (total 34 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   duration                     25195 non-null  float64
#  1   src_bytes                    25195 non-null  float64
#  2   dst_bytes                    25195 non-null  float64
#  3   wrong_fragment               25195 non-null  float64
#  4   urgent                       25195 non-null  float64
#  5   hot                          25195 non-null  float64
#  6   num_failed_logins            25195 non-null  float64
#  7   num_compromised              25195 non-null  float64
#  8   root_shell                   25195 non-null  float64
#  9   su_attempted                 25195 non-null  float64
#  10  num_root                     25195 non-null  float64
#  11  num_file_creations           25195 non-null  float64
# ...

# %%
test_set_copy = imputer.transform(test_set_copy)

# %%
test_set_copy = pd.DataFrame(test_set_copy, columns=test_set.select_dtypes(exclude=['object']).columns)
test_set_copy
# Out:
#        duration  src_bytes  ...  dst_host_rerror_rate  dst_host_srv_rerror_rate
# 0           0.0       31.0  ...                  0.00                      0.00
# 1           0.0        0.0  ...                  1.00                      1.00
# 2           0.0        0.0  ...                  0.54                      1.00
# 3           0.0      229.0  ...                  0.00                      0.00
# 4           0.0      250.0  ...                  0.00                      0.00
# ...         ...        ...  ...                   ...                       ...
# 25190       0.0        0.0  ...                  0.00                      0.00
# 25191       0.0      323.0  ...                  0.00                      0.00
# 25192       0.0        0.0  ...                  1.00                      0.96
# 25193       0.0        0.0  ...                  0.00                      0.00
# 25194       0.0      231.0  ...                  0.00                      0.00
#
# ...
